# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Othercomputers/My Computer/PycharmProjects/Bigscity-LibCity/
# %cd /content/drive/MyDrive/MultiSTGraph/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/MultiSTGraph

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct  7 02:25:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# import torchtext
# torchtext.__version__
# !pip3 install ray
# !pip3 install -U torchtext
# !pip3 install -U hyperopt
# !pip3 install dgl
# !pip3 install dtaidistance
# !pip3 install --upgrade gensim
# !pip3 install torch==1.10.2+cu113 torchvision==0.11.3+cu113 -f https://download.pytorch.org/whl/torch_stable.html 
# !pip3 install torchtext==0.10.0

# %%
import torch
print(torch.__version__)
import argparse
from libcity.pipeline import run_model
from libcity.utils import str2bool, add_general_args

# 'MultiATGCN', 'GMAN', 'ASTGCN', 'STTN', 'STGCN', 'AGCRN', 'MTGNN', 'GWNET', "GRU", 'LSTM', 'RNN', 'Seq2Seq', 'FNN', 'STSGCN', 'TGCN', 'DCRNN'
model_list = ['MultiATGCN', 'GMAN', 'STSGCN', 'ASTGCN', 'STTN', 'STGCN', 'AGCRN', 'MTGNN', 'GWNET', "GRU", 'LSTM', 'RNN', 'Seq2Seq', 'FNN',  'TGCN', 'DCRNN']
if __name__ == '__main__':
    for model_name in model_list:
        parser = argparse.ArgumentParser()
        parser.add_argument('--task', type=str, default='traffic_state_pred', help='the name of task')
        parser.add_argument('--model', type=str, default=model_name, help='the name of model')
        parser.add_argument('--dataset', type=str, default='201901010601_DC_SG_CTractFIPS_Hourly_Single_GP',
                            help='the name of dataset')
        parser.add_argument('--config_file', type=str, default='config_user', help='the file name of config file')
        parser.add_argument('--saved_model', type=str2bool, default=True, help='whether save the trained model')
        parser.add_argument('--train', type=str2bool, default=True, help='whether re-train if the model is trained')
        parser.add_argument('--exp_id', type=str, default=None, help='id of experiment')
        parser.add_argument('--seed', type=int, default=0, help='random seed')
        parser.add_argument('--start_dim', type=int, default=0, help='start_dim')
        parser.add_argument('--end_dim', type=int, default=1, help='end_dim')
        add_general_args(parser)
        args, unknown = parser.parse_known_args()
        dict_args = vars(args)
        other_args = {key: val for key, val in dict_args.items() if key not in
                      ['task', 'model', 'dataset', 'config_file', 'saved_model', 'train'] and val is not None}
        run_model(task=args.task, model_name=args.model, dataset_name=args.dataset, config_file=args.config_file,
                  saved_model=args.saved_model, train=args.train, other_args=other_args)
# Out:
# 1.10.2+cu113
# /content/drive/MyDrive/MultiSTGraph/libcity/pipeline/pipeline.py:3: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
#   from ray.tune.suggest.hyperopt import HyperOptSearch
# /content/drive/MyDrive/MultiSTGraph/libcity/pipeline/pipeline.py:3: DeprecationWarning: The module `ray.tune.suggest.hyperopt` has been moved to `ray.tune.search.hyperopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.hyperopt` with `ray.tune.search.hyperopt`.
#   from ray.tune.suggest.hyperopt import HyperOptSearch
# /content/drive/MyDrive/MultiSTGraph/libcity/pipeline/pipeline.py:4: DeprecationWarning: The module `ray.tune.suggest.bayesopt` has been moved to `ray.tune.search.bayesopt` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.bayesopt` with `ray.tune.search.bayesopt`.
#   from ray.tune.suggest.bayesopt import BayesOptSearch
# /content/drive/MyDrive/MultiSTGraph/libcity/pipeline/pipeline.py:5: DeprecationWarning: The module `ray.tune.suggest.basic_variant` has been moved to `ray.tune.search.basic_variant` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.basic_variant` with `ray.tune.search.basic_variant`.
#   from ray.tune.suggest.basic_variant import BasicVariantGenerator
# INFO:root:Log directory: ./libcity/log
# 2022-10-07 02:33:33,605 - INFO - Log directory: ./libcity/log
# INFO:root:Begin pipeline, task=traffic_state_pred, model_name=MultiATGCN, dataset_name=201901010601_DC_SG_CTractFIPS_Hourly_Single_GP, exp_id=11589
# 2022-10-07 02:33:33,614 - INFO - Begin pipeline, task=traffic_state_pred, model_name=MultiATGCN, dataset_name=201901010601_DC_SG_CTractFIPS_Hourly_Single_GP, exp_id=11589
# INFO:root:{'task': 'traffic_state_pred', 'model': 'MultiATGCN', 'dataset': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'saved_model': True, 'train': True, 'seed': 0, 'start_dim': 0, 'end_dim': 1, 'max_epoch': 30, 'train_rate': 0.7, 'eval_rate': 0.15, 'input_window': 24, 'output_window': 6, 'load_external': True, 'load_dynamic': False, 'add_time_in_day': True, 'add_day_in_week': False, 'hour_each_day': 24, 'interval_period': 7, 'interval_trend': 28, 'len_closeness': 1, 'len_period': 1, 'len_trend': 1, 'use_early_stop': True, 'patience': 6, 'dataset_class': 'MTHDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'embed_dim': 20, 'rnn_units': 64, 'num_layers': 2, 'cheb_order': 2, 'use_3tu': True, 'bidir_adj_mx': False, 'future_known': 2, 'batch_size': 16, 'atten': False, 's2s': False, 'adpadj': 'bidirection', 'adjtype': 'od', 'scaler': 'standard', 'add_static': True, 'normal_external': False, 'ext_scaler': 'none', 'learner': 'adam', 'learning_rate': 0.003, 'lr_decay': True, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.75, 'steps': [5, 10, 20, 30], 'clip_grad_norm': True, 'max_grad_norm': 5, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'link_weight': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'Visits': 'num'}}, 'ext': {'ext_id': 'num', 'time': 'other', 'holiday': 'num', 'weekend': 'num', 'wind': 'num', 'temp': 'num', 'rain': 'num', 'snow': 'num', 'vis': 'num', 'New_cases': 'num'}, 'data_col': ['Visits'], 'weight_col': 'link_weight', 'ext_col': ['holiday', 'weekend', 'wind', 'temp', 'rain', 'snow', 'vis'], 'data_files': ['201901010601_DC_SG_CTractFIPS_Hourly_Single_GP'], 'geo_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'rel_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'ext_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'output_dim': 1, 'time_intervals': 3600, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1, 'device': device(type='cuda', index=0), 'exp_id': 11589}
# 2022-10-07 02:33:33,620 - INFO - {'task': 'traffic_state_pred', 'model': 'MultiATGCN', 'dataset': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'saved_model': True, 'train': True, 'seed': 0, 'start_dim': 0, 'end_dim': 1, 'max_epoch': 30, 'train_rate': 0.7, 'eval_rate': 0.15, 'input_window': 24, 'output_window': 6, 'load_external': True, 'load_dynamic': False, 'add_time_in_day': True, 'add_day_in_week': False, 'hour_each_day': 24, 'interval_period': 7, 'interval_trend': 28, 'len_closeness': 1, 'len_period': 1, 'len_trend': 1, 'use_early_stop': True, 'patience': 6, 'dataset_class': 'MTHDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'embed_dim': 20, 'rnn_units': 64, 'num_layers': 2, 'cheb_order': 2, 'use_3tu': True, 'bidir_adj_mx': False, 'future_known': 2, 'batch_size': 16, 'atten': False, 's2s': False, 'adpadj': 'bidirection', 'adjtype': 'od', 'scaler': 'standard', 'add_static': True, 'normal_external': False, 'ext_scaler': 'none', 'learner': 'adam', 'learning_rate': 0.003, 'lr_decay': True, 'lr_scheduler': 'multisteplr', 'lr_decay_ratio': 0.75, 'steps': [5, 10, 20, 30], 'clip_grad_norm': True, 'max_grad_norm': 5, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_patience': 10, 'lr_threshold': 0.0001, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'link_weight': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'Visits': 'num'}}, 'ext': {'ext_id': 'num', 'time': 'other', 'holiday': 'num', 'weekend': 'num', 'wind': 'num', 'temp': 'num', 'rain': 'num', 'snow': 'num', 'vis': 'num', 'New_cases': 'num'}, 'data_col': ['Visits'], 'weight_col': 'link_weight', 'ext_col': ['holiday', 'weekend', 'wind', 'temp', 'rain', 'snow', 'vis'], 'data_files': ['201901010601_DC_SG_CTractFIPS_Hourly_Single_GP'], 'geo_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'rel_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'ext_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'output_dim': 1, 'time_intervals': 3600, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1, 'device': device(type='cuda', index=0), 'exp_id': 11589}
# INFO:root:Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.geo, num_nodes=234
# 2022-10-07 02:33:39,195 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.geo, num_nodes=234
# INFO:root:set_weight_link_or_dist: dist
# 2022-10-07 02:33:39,737 - INFO - set_weight_link_or_dist: dist
# INFO:root:init_weight_inf_or_zero: zero
# 2022-10-07 02:33:39,749 - INFO - init_weight_inf_or_zero: zero
# INFO:root:Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.rel, shape=(234, 234)
# 2022-10-07 02:33:39,874 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.rel, shape=(234, 234)
# INFO:root:Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.ext, shape=(3624, 7)
# 2022-10-07 02:33:40,072 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.ext, shape=(3624, 7)
# INFO:root:Loading file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.dyna
# 2022-10-07 02:33:40,077 - INFO - Loading file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.dyna
# INFO:root:Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.dyna, shape=(3624, 234, 1)
# 2022-10-07 02:33:41,487 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.dyna, shape=(3624, 234, 1)
# INFO:root:closeness: (2929, 24, 234, 2)
# 2022-10-07 02:33:42,236 - INFO - closeness: (2929, 24, 234, 2)
# INFO:root:period: (2929, 24, 234, 2)
# 2022-10-07 02:33:42,465 - INFO - period: (2929, 24, 234, 2)
# INFO:root:trend: (2929, 24, 234, 2)
# 2022-10-07 02:33:42,756 - INFO - trend: (2929, 24, 234, 2)
# INFO:root:Dataset created
# 2022-10-07 02:33:44,489 - INFO - Dataset created
# INFO:root:x shape: (2929, 72, 234, 2), y shape: (2929, 6, 234, 2)
# 2022-10-07 02:33:44,496 - INFO - x shape: (2929, 72, 234, 2), y shape: (2929, 6, 234, 2)
# INFO:root:train	x: (2050, 72, 234, 2), y: (2050, 6, 234, 2)
# 2022-10-07 02:33:44,528 - INFO - train	x: (2050, 72, 234, 2), y: (2050, 6, 234, 2)
# INFO:root:eval	x: (440, 72, 234, 2), y: (440, 6, 234, 2)
# 2022-10-07 02:33:44,535 - INFO - eval	x: (440, 72, 234, 2), y: (440, 6, 234, 2)
# INFO:root:test	x: (439, 72, 234, 2), y: (439, 6, 234, 2)
# 2022-10-07 02:33:44,541 - INFO - test	x: (439, 72, 234, 2), y: (439, 6, 234, 2)
# INFO:root:Saved at ./libcity/cache/dataset_cache/point_based_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_1_1_1_7_28_24_6_0.7_0.15_standard_16_True_False_True_False_True.npz
# 2022-10-07 02:34:17,710 - INFO - Saved at ./libcity/cache/dataset_cache/point_based_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_1_1_1_7_28_24_6_0.7_0.15_standard_16_True_False_True_False_True.npz
# INFO:root:StandardScaler mean: -0.037505123511445006, std: 0.9624896096625584
# 2022-10-07 02:34:17,937 - INFO - StandardScaler mean: -0.037505123511445006, std: 0.9624896096625584
# INFO:root:NoneScaler
# 2022-10-07 02:34:17,943 - INFO - NoneScaler
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# /content/drive/MyDrive/MultiSTGraph/libcity/model/traffic_flow_prediction/MultiATGCN.py:204: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   str.replace('[', ',').str.replace(']', ',').str.split(r',', expand=True)[[1, 2]].astype(float)
# INFO:root:MultiATGCN(
#   (static_initial): Sequential(
#     (embd): Linear(in_features=20, out_features=20, bias=True)
#     (relu1): ReLU()
#   )
#   (weight_ts): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 1x24x234x1 (GPU 0)]
#       (1): Parameter containing: [torch.cuda.FloatTensor of size 1x24x234x1 (GPU 0)]
#       (2): Parameter containing: [torch.cuda.FloatTensor of size 1x24x234x1 (GPU 0)]
#   )
#   (weight_tsg): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#       (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#       (2): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#   )
#   (static_fc): Sequential(
#     (embd): Linear(in_features=23, out_features=64, bias=True)
#     (relu1): ReLU()
#   )
#   (encoder): ATGRUEncoder(
#     (agru_cells): ModuleList(
#       (0): ATGRUCell(
#         (gate): AGCN()
#         (update): AGCN()
#       )
#       (1): ATGRUCell(
#         (gate): AGCN()
#         (update): AGCN()
#       )
#     )
#   )
#   (end_conv): Conv2d(24, 6, kernel_size=(1, 64), stride=(1, 1))
# )
# 2022-10-07 02:34:43,166 - INFO - MultiATGCN(
#   (static_initial): Sequential(
#     (embd): Linear(in_features=20, out_features=20, bias=True)
#     (relu1): ReLU()
#   )
#   (weight_ts): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 1x24x234x1 (GPU 0)]
#       (1): Parameter containing: [torch.cuda.FloatTensor of size 1x24x234x1 (GPU 0)]
#       (2): Parameter containing: [torch.cuda.FloatTensor of size 1x24x234x1 (GPU 0)]
#   )
#   (weight_tsg): ParameterList(
#       (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#       (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#       (2): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 0)]
#   )
#   (static_fc): Sequential(
#     (embd): Linear(in_features=23, out_features=64, bias=True)
#     (relu1): ReLU()
#   )
#   (encoder): ATGRUEncoder(
#     (agru_cells): ModuleList(
#       (0): ATGRUCell(
#         (gate): AGCN()
#         (update): AGCN()
#       )
#       (1): ATGRUCell(
#         (gate): AGCN()
#         (update): AGCN()
#       )
#     )
#   )
#   (end_conv): Conv2d(24, 6, kernel_size=(1, 64), stride=(1, 1))
# )
# INFO:root:node_emb	torch.Size([234, 20])	cuda:0	True
# 2022-10-07 02:34:43,173 - INFO - node_emb	torch.Size([234, 20])	cuda:0	True
# INFO:root:node_vec1	torch.Size([234, 20])	cuda:0	True
# 2022-10-07 02:34:43,183 - INFO - node_vec1	torch.Size([234, 20])	cuda:0	True
# INFO:root:node_vec2	torch.Size([20, 234])	cuda:0	True
# 2022-10-07 02:34:43,187 - INFO - node_vec2	torch.Size([20, 234])	cuda:0	True
# INFO:root:static_initial.embd.weight	torch.Size([20, 20])	cuda:0	True
# 2022-10-07 02:34:43,190 - INFO - static_initial.embd.weight	torch.Size([20, 20])	cuda:0	True
# INFO:root:static_initial.embd.bias	torch.Size([20])	cuda:0	True
# 2022-10-07 02:34:43,194 - INFO - static_initial.embd.bias	torch.Size([20])	cuda:0	True
# INFO:root:weight_ts.0	torch.Size([1, 24, 234, 1])	cuda:0	True
# 2022-10-07 02:34:43,199 - INFO - weight_ts.0	torch.Size([1, 24, 234, 1])	cuda:0	True
# INFO:root:weight_ts.1	torch.Size([1, 24, 234, 1])	cuda:0	True
# 2022-10-07 02:34:43,205 - INFO - weight_ts.1	torch.Size([1, 24, 234, 1])	cuda:0	True
# INFO:root:weight_ts.2	torch.Size([1, 24, 234, 1])	cuda:0	True
# 2022-10-07 02:34:43,208 - INFO - weight_ts.2	torch.Size([1, 24, 234, 1])	cuda:0	True
# INFO:root:weight_tsg.0	torch.Size([1])	cuda:0	True
# 2022-10-07 02:34:43,214 - INFO - weight_tsg.0	torch.Size([1])	cuda:0	True
# INFO:root:weight_tsg.1	torch.Size([1])	cuda:0	True
# 2022-10-07 02:34:43,216 - INFO - weight_tsg.1	torch.Size([1])	cuda:0	True
# INFO:root:weight_tsg.2	torch.Size([1])	cuda:0	True
# 2022-10-07 02:34:43,219 - INFO - weight_tsg.2	torch.Size([1])	cuda:0	True
# INFO:root:static_fc.embd.weight	torch.Size([64, 23])	cuda:0	True
# 2022-10-07 02:34:43,222 - INFO - static_fc.embd.weight	torch.Size([64, 23])	cuda:0	True
# INFO:root:static_fc.embd.bias	torch.Size([64])	cuda:0	True
# 2022-10-07 02:34:43,225 - INFO - static_fc.embd.bias	torch.Size([64])	cuda:0	True
# INFO:root:encoder.agru_cells.0.gate.weights_pool	torch.Size([20, 2, 66, 128])	cuda:0	True
# 2022-10-07 02:34:43,228 - INFO - encoder.agru_cells.0.gate.weights_pool	torch.Size([20, 2, 66, 128])	cuda:0	True
# INFO:root:encoder.agru_cells.0.gate.bias_pool	torch.Size([20, 128])	cuda:0	True
# 2022-10-07 02:34:43,230 - INFO - encoder.agru_cells.0.gate.bias_pool	torch.Size([20, 128])	cuda:0	True
# INFO:root:encoder.agru_cells.0.update.weights_pool	torch.Size([20, 2, 66, 64])	cuda:0	True
# 2022-10-07 02:34:43,245 - INFO - encoder.agru_cells.0.update.weights_pool	torch.Size([20, 2, 66, 64])	cuda:0	True
# INFO:root:encoder.agru_cells.0.update.bias_pool	torch.Size([20, 64])	cuda:0	True
# 2022-10-07 02:34:43,250 - INFO - encoder.agru_cells.0.update.bias_pool	torch.Size([20, 64])	cuda:0	True
# INFO:root:encoder.agru_cells.1.gate.weights_pool	torch.Size([20, 2, 128, 128])	cuda:0	True
# 2022-10-07 02:34:43,255 - INFO - encoder.agru_cells.1.gate.weights_pool	torch.Size([20, 2, 128, 128])	cuda:0	True
# INFO:root:encoder.agru_cells.1.gate.bias_pool	torch.Size([20, 128])	cuda:0	True
# 2022-10-07 02:34:43,259 - INFO - encoder.agru_cells.1.gate.bias_pool	torch.Size([20, 128])	cuda:0	True
# INFO:root:encoder.agru_cells.1.update.weights_pool	torch.Size([20, 2, 128, 64])	cuda:0	True
# 2022-10-07 02:34:43,263 - INFO - encoder.agru_cells.1.update.weights_pool	torch.Size([20, 2, 128, 64])	cuda:0	True
# INFO:root:encoder.agru_cells.1.update.bias_pool	torch.Size([20, 64])	cuda:0	True
# 2022-10-07 02:34:43,268 - INFO - encoder.agru_cells.1.update.bias_pool	torch.Size([20, 64])	cuda:0	True
# INFO:root:end_conv.weight	torch.Size([6, 24, 1, 64])	cuda:0	True
# 2022-10-07 02:34:43,271 - INFO - end_conv.weight	torch.Size([6, 24, 1, 64])	cuda:0	True
# INFO:root:end_conv.bias	torch.Size([6])	cuda:0	True
# 2022-10-07 02:34:43,274 - INFO - end_conv.bias	torch.Size([6])	cuda:0	True
# INFO:root:Total parameter numbers: 1539669
# 2022-10-07 02:34:43,289 - INFO - Total parameter numbers: 1539669
# INFO:root:You select `adam` optimizer.
# 2022-10-07 02:34:43,295 - INFO - You select `adam` optimizer.
# INFO:root:You select `multisteplr` lr_scheduler.
# 2022-10-07 02:34:43,300 - INFO - You select `multisteplr` lr_scheduler.
# WARNING:root:Received none train loss func and will use the loss func defined in the model.
# 2022-10-07 02:34:43,307 - WARNING - Received none train loss func and will use the loss func defined in the model.
# INFO:root:Start training ...
# 2022-10-07 02:34:43,310 - INFO - Start training ...
# INFO:root:num_batches:129
# 2022-10-07 02:34:43,313 - INFO - num_batches:129
# INFO:root:epoch complete!
# 2022-10-07 02:35:16,621 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:35:16,628 - INFO - evaluating now!
# INFO:root:Epoch [0/30] train_loss: 0.5732, val_loss: 0.4522, lr: 0.003000, 35.75s
# 2022-10-07 02:35:19,066 - INFO - Epoch [0/30] train_loss: 0.5732, val_loss: 0.4522, lr: 0.003000, 35.75s
# INFO:root:Saved model at 0
# 2022-10-07 02:35:19,144 - INFO - Saved model at 0
# INFO:root:Val loss decrease from inf to 0.4522, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch0.tar
# 2022-10-07 02:35:19,153 - INFO - Val loss decrease from inf to 0.4522, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch0.tar
# INFO:root:epoch complete!
# 2022-10-07 02:35:49,876 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:35:49,881 - INFO - evaluating now!
# INFO:root:Epoch [1/30] train_loss: 0.4113, val_loss: 0.4145, lr: 0.003000, 33.17s
# 2022-10-07 02:35:52,335 - INFO - Epoch [1/30] train_loss: 0.4113, val_loss: 0.4145, lr: 0.003000, 33.17s
# INFO:root:Saved model at 1
# 2022-10-07 02:35:52,405 - INFO - Saved model at 1
# INFO:root:Val loss decrease from 0.4522 to 0.4145, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch1.tar
# 2022-10-07 02:35:52,413 - INFO - Val loss decrease from 0.4522 to 0.4145, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch1.tar
# INFO:root:epoch complete!
# 2022-10-07 02:36:23,734 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:36:23,745 - INFO - evaluating now!
# INFO:root:Epoch [2/30] train_loss: 0.3939, val_loss: 0.3952, lr: 0.003000, 34.45s
# 2022-10-07 02:36:26,880 - INFO - Epoch [2/30] train_loss: 0.3939, val_loss: 0.3952, lr: 0.003000, 34.45s
# INFO:root:Saved model at 2
# 2022-10-07 02:36:26,972 - INFO - Saved model at 2
# INFO:root:Val loss decrease from 0.4145 to 0.3952, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch2.tar
# 2022-10-07 02:36:26,984 - INFO - Val loss decrease from 0.4145 to 0.3952, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch2.tar
# INFO:root:epoch complete!
# 2022-10-07 02:36:58,673 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:36:58,682 - INFO - evaluating now!
# INFO:root:Epoch [3/30] train_loss: 0.3770, val_loss: 0.3917, lr: 0.003000, 34.13s
# 2022-10-07 02:37:01,117 - INFO - Epoch [3/30] train_loss: 0.3770, val_loss: 0.3917, lr: 0.003000, 34.13s
# INFO:root:Saved model at 3
# 2022-10-07 02:37:01,189 - INFO - Saved model at 3
# INFO:root:Val loss decrease from 0.3952 to 0.3917, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch3.tar
# 2022-10-07 02:37:01,196 - INFO - Val loss decrease from 0.3952 to 0.3917, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch3.tar
# INFO:root:epoch complete!
# 2022-10-07 02:37:32,595 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:37:32,604 - INFO - evaluating now!
# INFO:root:Epoch [4/30] train_loss: 0.3717, val_loss: 0.3842, lr: 0.002250, 33.81s
# 2022-10-07 02:37:35,009 - INFO - Epoch [4/30] train_loss: 0.3717, val_loss: 0.3842, lr: 0.002250, 33.81s
# INFO:root:Saved model at 4
# 2022-10-07 02:37:35,087 - INFO - Saved model at 4
# INFO:root:Val loss decrease from 0.3917 to 0.3842, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch4.tar
# 2022-10-07 02:37:35,096 - INFO - Val loss decrease from 0.3917 to 0.3842, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch4.tar
# INFO:root:epoch complete!
# 2022-10-07 02:38:06,442 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:38:06,449 - INFO - evaluating now!
# INFO:root:Epoch [5/30] train_loss: 0.3664, val_loss: 0.3819, lr: 0.002250, 33.80s
# 2022-10-07 02:38:08,908 - INFO - Epoch [5/30] train_loss: 0.3664, val_loss: 0.3819, lr: 0.002250, 33.80s
# INFO:root:Saved model at 5
# 2022-10-07 02:38:09,026 - INFO - Saved model at 5
# INFO:root:Val loss decrease from 0.3842 to 0.3819, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch5.tar
# 2022-10-07 02:38:09,032 - INFO - Val loss decrease from 0.3842 to 0.3819, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch5.tar
# INFO:root:epoch complete!
# 2022-10-07 02:38:40,485 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:38:40,492 - INFO - evaluating now!
# INFO:root:Epoch [6/30] train_loss: 0.3632, val_loss: 0.3807, lr: 0.002250, 33.87s
# 2022-10-07 02:38:42,910 - INFO - Epoch [6/30] train_loss: 0.3632, val_loss: 0.3807, lr: 0.002250, 33.87s
# INFO:root:Saved model at 6
# 2022-10-07 02:38:42,978 - INFO - Saved model at 6
# INFO:root:Val loss decrease from 0.3819 to 0.3807, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch6.tar
# 2022-10-07 02:38:42,988 - INFO - Val loss decrease from 0.3819 to 0.3807, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch6.tar
# INFO:root:epoch complete!
# 2022-10-07 02:39:15,112 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:39:15,120 - INFO - evaluating now!
# INFO:root:Epoch [7/30] train_loss: 0.3622, val_loss: 0.3771, lr: 0.002250, 34.56s
# 2022-10-07 02:39:17,555 - INFO - Epoch [7/30] train_loss: 0.3622, val_loss: 0.3771, lr: 0.002250, 34.56s
# INFO:root:Saved model at 7
# 2022-10-07 02:39:17,626 - INFO - Saved model at 7
# INFO:root:Val loss decrease from 0.3807 to 0.3771, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch7.tar
# 2022-10-07 02:39:17,631 - INFO - Val loss decrease from 0.3807 to 0.3771, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch7.tar
# INFO:root:epoch complete!
# 2022-10-07 02:39:48,955 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:39:48,963 - INFO - evaluating now!
# INFO:root:Epoch [8/30] train_loss: 0.3592, val_loss: 0.3768, lr: 0.002250, 33.79s
# 2022-10-07 02:39:51,424 - INFO - Epoch [8/30] train_loss: 0.3592, val_loss: 0.3768, lr: 0.002250, 33.79s
# INFO:root:Saved model at 8
# 2022-10-07 02:39:51,500 - INFO - Saved model at 8
# INFO:root:Val loss decrease from 0.3771 to 0.3768, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch8.tar
# 2022-10-07 02:39:51,507 - INFO - Val loss decrease from 0.3771 to 0.3768, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch8.tar
# INFO:root:epoch complete!
# 2022-10-07 02:40:22,911 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:40:22,919 - INFO - evaluating now!
# INFO:root:Epoch [9/30] train_loss: 0.3563, val_loss: 0.3758, lr: 0.001688, 33.83s
# 2022-10-07 02:40:25,342 - INFO - Epoch [9/30] train_loss: 0.3563, val_loss: 0.3758, lr: 0.001688, 33.83s
# INFO:root:Saved model at 9
# 2022-10-07 02:40:25,417 - INFO - Saved model at 9
# INFO:root:Val loss decrease from 0.3768 to 0.3758, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch9.tar
# 2022-10-07 02:40:25,422 - INFO - Val loss decrease from 0.3768 to 0.3758, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch9.tar
# INFO:root:epoch complete!
# 2022-10-07 02:40:56,790 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:40:56,798 - INFO - evaluating now!
# INFO:root:Epoch [10/30] train_loss: 0.3520, val_loss: 0.3757, lr: 0.001688, 33.79s
# 2022-10-07 02:40:59,219 - INFO - Epoch [10/30] train_loss: 0.3520, val_loss: 0.3757, lr: 0.001688, 33.79s
# INFO:root:Saved model at 10
# 2022-10-07 02:40:59,297 - INFO - Saved model at 10
# INFO:root:Val loss decrease from 0.3758 to 0.3757, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch10.tar
# 2022-10-07 02:40:59,303 - INFO - Val loss decrease from 0.3758 to 0.3757, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch10.tar
# INFO:root:epoch complete!
# 2022-10-07 02:41:30,732 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:41:30,739 - INFO - evaluating now!
# INFO:root:Epoch [11/30] train_loss: 0.3498, val_loss: 0.3757, lr: 0.001688, 33.88s
# 2022-10-07 02:41:33,192 - INFO - Epoch [11/30] train_loss: 0.3498, val_loss: 0.3757, lr: 0.001688, 33.88s
# INFO:root:Saved model at 11
# 2022-10-07 02:41:33,269 - INFO - Saved model at 11
# INFO:root:Val loss decrease from 0.3757 to 0.3757, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch11.tar
# 2022-10-07 02:41:33,279 - INFO - Val loss decrease from 0.3757 to 0.3757, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch11.tar
# INFO:root:epoch complete!
# 2022-10-07 02:42:05,508 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:42:05,516 - INFO - evaluating now!
# INFO:root:Epoch [12/30] train_loss: 0.3476, val_loss: 0.3796, lr: 0.001688, 34.64s
# 2022-10-07 02:42:07,926 - INFO - Epoch [12/30] train_loss: 0.3476, val_loss: 0.3796, lr: 0.001688, 34.64s
# INFO:root:epoch complete!
# 2022-10-07 02:42:39,274 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:42:39,283 - INFO - evaluating now!
# INFO:root:Epoch [13/30] train_loss: 0.3464, val_loss: 0.3738, lr: 0.001688, 33.78s
# 2022-10-07 02:42:41,710 - INFO - Epoch [13/30] train_loss: 0.3464, val_loss: 0.3738, lr: 0.001688, 33.78s
# INFO:root:Saved model at 13
# 2022-10-07 02:42:41,783 - INFO - Saved model at 13
# INFO:root:Val loss decrease from 0.3757 to 0.3738, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 02:42:41,790 - INFO - Val loss decrease from 0.3757 to 0.3738, saving to ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# INFO:root:epoch complete!
# 2022-10-07 02:43:13,091 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:43:13,096 - INFO - evaluating now!
# INFO:root:Epoch [14/30] train_loss: 0.3441, val_loss: 0.3789, lr: 0.001688, 33.71s
# 2022-10-07 02:43:15,505 - INFO - Epoch [14/30] train_loss: 0.3441, val_loss: 0.3789, lr: 0.001688, 33.71s
# INFO:root:epoch complete!
# 2022-10-07 02:43:46,800 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:43:46,806 - INFO - evaluating now!
# INFO:root:Epoch [15/30] train_loss: 0.3427, val_loss: 0.3855, lr: 0.001688, 33.73s
# 2022-10-07 02:43:49,241 - INFO - Epoch [15/30] train_loss: 0.3427, val_loss: 0.3855, lr: 0.001688, 33.73s
# INFO:root:epoch complete!
# 2022-10-07 02:44:21,292 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:44:21,301 - INFO - evaluating now!
# INFO:root:Epoch [16/30] train_loss: 0.3419, val_loss: 0.3791, lr: 0.001688, 34.48s
# 2022-10-07 02:44:23,733 - INFO - Epoch [16/30] train_loss: 0.3419, val_loss: 0.3791, lr: 0.001688, 34.48s
# INFO:root:epoch complete!
# 2022-10-07 02:44:54,997 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:44:55,005 - INFO - evaluating now!
# INFO:root:Epoch [17/30] train_loss: 0.3397, val_loss: 0.3812, lr: 0.001688, 33.67s
# 2022-10-07 02:44:57,413 - INFO - Epoch [17/30] train_loss: 0.3397, val_loss: 0.3812, lr: 0.001688, 33.67s
# INFO:root:epoch complete!
# 2022-10-07 02:45:28,676 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:45:28,683 - INFO - evaluating now!
# INFO:root:Epoch [18/30] train_loss: 0.3379, val_loss: 0.3796, lr: 0.001688, 33.67s
# 2022-10-07 02:45:31,094 - INFO - Epoch [18/30] train_loss: 0.3379, val_loss: 0.3796, lr: 0.001688, 33.67s
# INFO:root:epoch complete!
# 2022-10-07 02:46:02,330 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 02:46:02,335 - INFO - evaluating now!
# INFO:root:Epoch [19/30] train_loss: 0.3368, val_loss: 0.3803, lr: 0.001266, 33.64s
# 2022-10-07 02:46:04,742 - INFO - Epoch [19/30] train_loss: 0.3368, val_loss: 0.3803, lr: 0.001266, 33.64s
# WARNING:root:Early stopping at epoch: 19
# 2022-10-07 02:46:04,747 - WARNING - Early stopping at epoch: 19
# INFO:root:Trained totally 20 epochs, average train time is 31.536s, average eval time is 2.458s
# 2022-10-07 02:46:04,754 - INFO - Trained totally 20 epochs, average train time is 31.536s, average eval time is 2.458s
# INFO:root:Loaded model at 13
# 2022-10-07 02:46:04,818 - INFO - Loaded model at 13
# INFO:root:Saved model at ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.m
# 2022-10-07 02:46:04,827 - INFO - Saved model at ./libcity/cache/11589/model_cache/MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.m
# INFO:root:Start evaluating ...
# 2022-10-07 02:46:04,909 - INFO - Start evaluating ...
# INFO:root:Note that you select the single mode to evaluate!
# 2022-10-07 02:46:07,631 - INFO - Note that you select the single mode to evaluate!
# INFO:root:Evaluate result is saved at ./libcity/cache/11589/evaluate_cache/2022_10_07_02_46_07_MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.csv
# 2022-10-07 02:46:07,648 - INFO - Evaluate result is saved at ./libcity/cache/11589/evaluate_cache/2022_10_07_02_46_07_MultiATGCN_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.csv
# INFO:root:
#         MAE  masked_MAE  masked_MAPE  masked_RMSE
# 1  0.365352    0.365301     2.297769     0.552885
# 2  0.371650    0.371581     2.448296     0.564855
# 3  0.375033    0.374967     2.575048     0.572523
# 4  0.378860    0.378787     2.700356     0.576397
# 5  0.378896    0.378823     2.650453     0.577835
# 6  0.380763    0.380693     2.604864     0.579308
# 2022-10-07 02:46:07,656 - INFO -
#         MAE  masked_MAE  masked_MAPE  masked_RMSE
# 1  0.365352    0.365301     2.297769     0.552885
# 2  0.371650    0.371581     2.448296     0.564855
# 3  0.375033    0.374967     2.575048     0.572523
# 4  0.378860    0.378787     2.700356     0.576397
# 5  0.378896    0.378823     2.650453     0.577835
# 6  0.380763    0.380693     2.604864     0.579308
# INFO:root:
# MAE            0.375092
# masked_MAE     0.375025
# masked_MAPE    2.546131
# masked_RMSE    0.570634
# dtype: float64
# 2022-10-07 02:46:07,665 - INFO -
# MAE            0.375092
# masked_MAE     0.375025
# masked_MAPE    2.546131
# masked_RMSE    0.570634
# dtype: float64
# INFO:root:Log directory: ./libcity/log
# 2022-10-07 02:46:08,241 - INFO - Log directory: ./libcity/log
# 2022-10-07 02:46:08,241 - INFO - Log directory: ./libcity/log
# INFO:root:Begin pipeline, task=traffic_state_pred, model_name=GMAN, dataset_name=201901010601_DC_SG_CTractFIPS_Hourly_Single_GP, exp_id=87124
# 2022-10-07 02:46:08,253 - INFO - Begin pipeline, task=traffic_state_pred, model_name=GMAN, dataset_name=201901010601_DC_SG_CTractFIPS_Hourly_Single_GP, exp_id=87124
# 2022-10-07 02:46:08,253 - INFO - Begin pipeline, task=traffic_state_pred, model_name=GMAN, dataset_name=201901010601_DC_SG_CTractFIPS_Hourly_Single_GP, exp_id=87124
# INFO:root:{'task': 'traffic_state_pred', 'model': 'GMAN', 'dataset': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'saved_model': True, 'train': True, 'seed': 0, 'start_dim': 0, 'end_dim': 1, 'max_epoch': 30, 'train_rate': 0.7, 'eval_rate': 0.15, 'input_window': 24, 'output_window': 6, 'load_external': True, 'load_dynamic': False, 'add_time_in_day': True, 'add_day_in_week': False, 'hour_each_day': 24, 'interval_period': 7, 'interval_trend': 28, 'len_closeness': 1, 'len_period': 1, 'len_trend': 1, 'use_early_stop': True, 'patience': 6, 'dataset_class': 'GMANDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'L': 2, 'K': 2, 'batch_size': 8, 'scaler': 'standard', 'learner': 'adam', 'learning_rate': 0.001, 'lr_decay': True, 'lr_scheduler': 'reducelronplateau', 'lr_decay_ratio': 0.7, 'lr_patience': 5, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'normal_external': False, 'ext_scaler': 'none', 'D': 64, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'link_weight': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'Visits': 'num'}}, 'ext': {'ext_id': 'num', 'time': 'other', 'holiday': 'num', 'weekend': 'num', 'wind': 'num', 'temp': 'num', 'rain': 'num', 'snow': 'num', 'vis': 'num', 'New_cases': 'num'}, 'data_col': ['Visits'], 'weight_col': 'link_weight', 'ext_col': ['holiday', 'weekend', 'wind', 'temp', 'rain', 'snow', 'vis'], 'data_files': ['201901010601_DC_SG_CTractFIPS_Hourly_Single_GP'], 'geo_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'rel_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'ext_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'output_dim': 1, 'time_intervals': 3600, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1, 'device': device(type='cuda', index=0), 'exp_id': 87124}
# 2022-10-07 02:46:08,260 - INFO - {'task': 'traffic_state_pred', 'model': 'GMAN', 'dataset': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'saved_model': True, 'train': True, 'seed': 0, 'start_dim': 0, 'end_dim': 1, 'max_epoch': 30, 'train_rate': 0.7, 'eval_rate': 0.15, 'input_window': 24, 'output_window': 6, 'load_external': True, 'load_dynamic': False, 'add_time_in_day': True, 'add_day_in_week': False, 'hour_each_day': 24, 'interval_period': 7, 'interval_trend': 28, 'len_closeness': 1, 'len_period': 1, 'len_trend': 1, 'use_early_stop': True, 'patience': 6, 'dataset_class': 'GMANDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'L': 2, 'K': 2, 'batch_size': 8, 'scaler': 'standard', 'learner': 'adam', 'learning_rate': 0.001, 'lr_decay': True, 'lr_scheduler': 'reducelronplateau', 'lr_decay_ratio': 0.7, 'lr_patience': 5, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'normal_external': False, 'ext_scaler': 'none', 'D': 64, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'link_weight': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'Visits': 'num'}}, 'ext': {'ext_id': 'num', 'time': 'other', 'holiday': 'num', 'weekend': 'num', 'wind': 'num', 'temp': 'num', 'rain': 'num', 'snow': 'num', 'vis': 'num', 'New_cases': 'num'}, 'data_col': ['Visits'], 'weight_col': 'link_weight', 'ext_col': ['holiday', 'weekend', 'wind', 'temp', 'rain', 'snow', 'vis'], 'data_files': ['201901010601_DC_SG_CTractFIPS_Hourly_Single_GP'], 'geo_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'rel_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'ext_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'output_dim': 1, 'time_intervals': 3600, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1, 'device': device(type='cuda', index=0), 'exp_id': 87124}
# 2022-10-07 02:46:08,260 - INFO - {'task': 'traffic_state_pred', 'model': 'GMAN', 'dataset': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'saved_model': True, 'train': True, 'seed': 0, 'start_dim': 0, 'end_dim': 1, 'max_epoch': 30, 'train_rate': 0.7, 'eval_rate': 0.15, 'input_window': 24, 'output_window': 6, 'load_external': True, 'load_dynamic': False, 'add_time_in_day': True, 'add_day_in_week': False, 'hour_each_day': 24, 'interval_period': 7, 'interval_trend': 28, 'len_closeness': 1, 'len_period': 1, 'len_trend': 1, 'use_early_stop': True, 'patience': 6, 'dataset_class': 'GMANDataset', 'executor': 'TrafficStateExecutor', 'evaluator': 'TrafficStateEvaluator', 'L': 2, 'K': 2, 'batch_size': 8, 'scaler': 'standard', 'learner': 'adam', 'learning_rate': 0.001, 'lr_decay': True, 'lr_scheduler': 'reducelronplateau', 'lr_decay_ratio': 0.7, 'lr_patience': 5, 'cache_dataset': True, 'num_workers': 0, 'pad_with_last_sample': True, 'normal_external': False, 'ext_scaler': 'none', 'D': 64, 'gpu': True, 'gpu_id': 0, 'train_loss': 'none', 'epoch': 0, 'weight_decay': 0, 'lr_epsilon': 1e-08, 'lr_beta1': 0.9, 'lr_beta2': 0.999, 'lr_alpha': 0.99, 'lr_momentum': 0, 'steps': [5, 20, 40, 70], 'step_size': 10, 'lr_T_max': 30, 'lr_eta_min': 0, 'lr_threshold': 0.0001, 'clip_grad_norm': False, 'max_grad_norm': 1.0, 'log_level': 'INFO', 'log_every': 1, 'load_best_epoch': True, 'hyper_tune': False, 'metrics': ['MAE', 'MAPE', 'MSE', 'RMSE', 'masked_MAE', 'masked_MAPE', 'masked_MSE', 'masked_RMSE', 'R2', 'EVAR'], 'evaluator_mode': 'single', 'save_mode': ['csv'], 'geo': {'including_types': ['Point'], 'Point': {}}, 'rel': {'including_types': ['geo'], 'geo': {'link_weight': 'num'}}, 'dyna': {'including_types': ['state'], 'state': {'entity_id': 'geo_id', 'Visits': 'num'}}, 'ext': {'ext_id': 'num', 'time': 'other', 'holiday': 'num', 'weekend': 'num', 'wind': 'num', 'temp': 'num', 'rain': 'num', 'snow': 'num', 'vis': 'num', 'New_cases': 'num'}, 'data_col': ['Visits'], 'weight_col': 'link_weight', 'ext_col': ['holiday', 'weekend', 'wind', 'temp', 'rain', 'snow', 'vis'], 'data_files': ['201901010601_DC_SG_CTractFIPS_Hourly_Single_GP'], 'geo_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'rel_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'ext_file': '201901010601_DC_SG_CTractFIPS_Hourly_Single_GP', 'output_dim': 1, 'time_intervals': 3600, 'init_weight_inf_or_zero': 'zero', 'set_weight_link_or_dist': 'dist', 'calculate_weight_adj': False, 'weight_adj_epsilon': 0.1, 'device': device(type='cuda', index=0), 'exp_id': 87124}
# INFO:root:Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.geo, num_nodes=234
# 2022-10-07 02:46:08,272 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.geo, num_nodes=234
# 2022-10-07 02:46:08,272 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.geo, num_nodes=234
# INFO:root:set_weight_link_or_dist: dist
# 2022-10-07 02:46:08,340 - INFO - set_weight_link_or_dist: dist
# 2022-10-07 02:46:08,340 - INFO - set_weight_link_or_dist: dist
# INFO:root:init_weight_inf_or_zero: zero
# 2022-10-07 02:46:08,351 - INFO - init_weight_inf_or_zero: zero
# 2022-10-07 02:46:08,351 - INFO - init_weight_inf_or_zero: zero
# INFO:root:Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.rel, shape=(234, 234)
# 2022-10-07 02:46:08,483 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.rel, shape=(234, 234)
# 2022-10-07 02:46:08,483 - INFO - Loaded file 201901010601_DC_SG_CTractFIPS_Hourly_Single_GP.rel, shape=(234, 234)
# Walk iteration:
# 1 / 100
# 2 / 100
# 3 / 100
# 4 / 100
# 5 / 100
# 6 / 100
# 7 / 100
# 8 / 100
# 9 / 100
# 10 / 100
# 11 / 100
# 12 / 100
# 13 / 100
# 14 / 100
# 15 / 100
# 16 / 100
# 17 / 100
# 18 / 100
# 19 / 100
# 20 / 100
# 21 / 100
# 22 / 100
# 23 / 100
# 24 / 100
# 25 / 100
# 26 / 100
# 27 / 100
# 28 / 100
# 29 / 100
# 30 / 100
# 31 / 100
# 32 / 100
# 33 / 100
# 34 / 100
# 35 / 100
# 36 / 100
# 37 / 100
# 38 / 100
# 39 / 100
# 40 / 100
# 41 / 100
# 42 / 100
# 43 / 100
# 44 / 100
# 45 / 100
# 46 / 100
# 47 / 100
# 48 / 100
# 49 / 100
# 50 / 100
# 51 / 100
# 52 / 100
# 53 / 100
# 54 / 100
# 55 / 100
# 56 / 100
# 57 / 100
# 58 / 100
# 59 / 100
# 60 / 100
# 61 / 100
# 62 / 100
# 63 / 100
# 64 / 100
# 65 / 100
# 66 / 100
# 67 / 100
# 68 / 100
# 69 / 100
# 70 / 100
# 71 / 100
# 72 / 100
# 73 / 100
# 74 / 100
# 75 / 100
# 76 / 100
# 77 / 100
# 78 / 100
# 79 / 100
# 80 / 100
# 81 / 100
# 82 / 100
# 83 / 100
# 84 / 100
# 85 / 100
# 86 / 100
# 87 / 100
# 88 / 100
# 89 / 100
# 90 / 100
# 91 / 100
# 92 / 100
# 93 / 100
# 94 / 100
# 95 / 100
# 96 / 100
# 97 / 100
# 98 / 100
# 99 / 100
# 100 / 100
# INFO:gensim.models.word2vec:collecting all words and their counts
# 2022-10-07 02:46:53,064 - INFO - collecting all words and their counts
# 2022-10-07 02:46:53,064 - INFO - collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-10-07 02:46:53,073 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-10-07 02:46:53,073 - INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 800000 words, keeping 234 word types
# 2022-10-07 02:46:53,212 - INFO - PROGRESS: at sentence #10000, processed 800000 words, keeping 234 word types
# 2022-10-07 02:46:53,212 - INFO - PROGRESS: at sentence #10000, processed 800000 words, keeping 234 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 1600000 words, keeping 234 word types
# 2022-10-07 02:46:53,337 - INFO - PROGRESS: at sentence #20000, processed 1600000 words, keeping 234 word types
# 2022-10-07 02:46:53,337 - INFO - PROGRESS: at sentence #20000, processed 1600000 words, keeping 234 word types
# INFO:gensim.models.word2vec:collected 234 word types from a corpus of 1872000 raw words and 23400 sentences
# 2022-10-07 02:46:53,395 - INFO - collected 234 word types from a corpus of 1872000 raw words and 23400 sentences
# 2022-10-07 02:46:53,395 - INFO - collected 234 word types from a corpus of 1872000 raw words and 23400 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# 2022-10-07 02:46:53,407 - INFO - Creating a fresh vocabulary
# 2022-10-07 02:46:53,407 - INFO - Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 234 unique words (100.00% of original 234, drops 0)', 'datetime': '2022-10-07T02:46:53.414094', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-10-07 02:46:53,414 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 234 unique words (100.00% of original 234, drops 0)', 'datetime': '2022-10-07T02:46:53.414094', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-10-07 02:46:53,414 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=0 retains 234 unique words (100.00% of original 234, drops 0)', 'datetime': '2022-10-07T02:46:53.414094', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 1872000 word corpus (100.00% of original 1872000, drops 0)', 'datetime': '2022-10-07T02:46:53.418921', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-10-07 02:46:53,418 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 1872000 word corpus (100.00% of original 1872000, drops 0)', 'datetime': '2022-10-07T02:46:53.418921', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-10-07 02:46:53,418 - INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=0 leaves 1872000 word corpus (100.00% of original 1872000, drops 0)', 'datetime': '2022-10-07T02:46:53.418921', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 234 items
# 2022-10-07 02:46:53,426 - INFO - deleting the raw counts dictionary of 234 items
# 2022-10-07 02:46:53,426 - INFO - deleting the raw counts dictionary of 234 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 205 most-common words
# 2022-10-07 02:46:53,430 - INFO - sample=0.001 downsamples 205 most-common words
# 2022-10-07 02:46:53,430 - INFO - sample=0.001 downsamples 205 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1321656.6672246957 word corpus (70.6%% of prior 1872000)', 'datetime': '2022-10-07T02:46:53.434244', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# 2022-10-07 02:46:53,434 - INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1321656.6672246957 word corpus (70.6%% of prior 1872000)', 'datetime': '2022-10-07T02:46:53.434244', 'gensim': '4.2.0', 'python': '3.7.14 (default, Sep  8 2022, 00:06:44) \n[GCC 7.5.0]', 'platform': 'Linux-5.10.133+-x86_64-with-Ubuntu-18.04-bionic', 'event': 'prepare_vocab'}
# ...
# 2022-10-07 05:06:43,108 - INFO - Epoch [12/30] train_loss: 0.3820, val_loss: 0.4155, lr: 0.001000, 44.56s
# 2022-10-07 05:06:43,108 - INFO - Epoch [12/30] train_loss: 0.3820, val_loss: 0.4155, lr: 0.001000, 44.56s
# INFO:root:Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# 2022-10-07 05:06:43,216 - INFO - Saved model at 12
# INFO:root:Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# 2022-10-07 05:06:43,235 - INFO - Val loss decrease from 0.4198 to 0.4155, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch12.tar
# INFO:root:epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# 2022-10-07 05:07:22,879 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# 2022-10-07 05:07:22,912 - INFO - evaluating now!
# INFO:root:Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# 2022-10-07 05:07:28,964 - INFO - Epoch [13/30] train_loss: 0.3776, val_loss: 0.4106, lr: 0.001000, 45.72s
# INFO:root:Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# 2022-10-07 05:07:29,101 - INFO - Saved model at 13
# INFO:root:Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# 2022-10-07 05:07:29,132 - INFO - Val loss decrease from 0.4155 to 0.4106, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch13.tar
# INFO:root:epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# 2022-10-07 05:08:09,243 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# 2022-10-07 05:08:09,270 - INFO - evaluating now!
# INFO:root:Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# 2022-10-07 05:08:14,460 - INFO - Epoch [14/30] train_loss: 0.3767, val_loss: 0.3979, lr: 0.001000, 45.31s
# INFO:root:Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# 2022-10-07 05:08:14,557 - INFO - Saved model at 14
# INFO:root:Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# 2022-10-07 05:08:14,586 - INFO - Val loss decrease from 0.4106 to 0.3979, saving to ./libcity/cache/88116/model_cache/GWNET_201901010601_DC_SG_CTractFIPS_Hourly_Single_GP_epoch14.tar
# INFO:root:epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# 2022-10-07 05:08:54,054 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# 2022-10-07 05:08:54,081 - INFO - evaluating now!
# INFO:root:Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# 2022-10-07 05:08:59,197 - INFO - Epoch [15/30] train_loss: 0.3736, val_loss: 0.4055, lr: 0.001000, 44.60s
# INFO:root:epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# 2022-10-07 05:09:38,575 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# 2022-10-07 05:09:38,593 - INFO - evaluating now!
# INFO:root:Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# 2022-10-07 05:09:43,731 - INFO - Epoch [16/30] train_loss: 0.3716, val_loss: 0.4044, lr: 0.001000, 44.51s
# INFO:root:epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# 2022-10-07 05:10:24,059 - INFO - epoch complete!
# INFO:root:evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
# 2022-10-07 05:10:24,091 - INFO - evaluating now!
